# %%
l1 = [1, 2]
l2 = [9, 7]

# %%
l1
# Out:
# [1, 2]

# %%
l2
# Out:
# [9, 7]

# %%
l3 = l1 + l2
l3
# Out:
# [1, 2, 9, 7]

# %%
l4 = l2 + l1
l4
# Out:
# [9, 7, 1, 2]

# %%
l1
# Out:
# [1, 2]

# %%
l1 * 2
# Out:
# [1, 2, 1, 2]

# %%
l5 = l1 * 3
l5
# Out:
# [1, 2, 1, 2, 1, 2]

# %%
l5
# Out:
# [1, 2, 1, 2, 1, 2]

# %%
l5[-1]
# Out:
# 2

# %%
l5[1::2]
# Out:
# [2, 2, 2]

# %%
l = [1,2]

# %%
l = [3,4]

# %%
l.append("a")
l
# Out:
# [3, 4, 'a']

# %%
l.append(["b", "c"])
l
# Out:
# [3, 4, 'a', ['b', 'c']]

# %%
len(l)
# Out:
# 4

# %%
l = [3, 4, 'a', ['b', 'c']]
l
# Out:
# [3, 4, 'a', ['b', 'c']]

# %%
l.extend(['b', 'c'])
l
# Out:
# [3, 4, 'a', ['b', 'c'], 'b', 'c']

# %%
l = [3, 4, 'a']
l
# Out:
# [3, 4, 'a']

# %%
l.insert(2, 5)
l
# Out:
# [3, 4, 5, 'a']

# %%
l.insert(2, "b")
l
# Out:
# [3, 4, 'b', 5, 'a']

# %%
l
# Out:
# [3, 4, 'b', 5, 'a']

# %%
l.pop()
l
# Out:
# [3, 4, 'b', 5]

# %%
l.pop(0)
l
# Out:
# [4, 'b', 5]

# %%
l
# Out:
# [4, 'b', 5]

# %%
l.remove('b')

# %%
l
# Out:
# [4, 5]

# %%
l.remove(7)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-54-6ead95561137> in <module>
# ----> 1 l.remove(7)
#
# ValueError: list.remove(x): x not in list

# %%
list1 = [1,'a',2.5,1+4j]
list1.remove(2.5)
print(list1)
# Out:
# [1, 'a', (1+4j)]

# %%
l = [1,5,3,8,0,3,54,9,8,9]
l
# Out:
# [1, 5, 3, 8, 0, 3, 54, 9, 8, 9]

# %%
max(l)
# Out:
# 54

# %%
min(l)
# Out:
# 0

# %%
l.count(9)
# Out:
# 2

# %%
len(l)
# Out:
# 10

# %%
l
# Out:
# [1, 5, 3, 8, 0, 3, 54, 9, 8, 9]

# %%
l.reverse()
print(l)

min()
max()
l.count()
len()
# Out:
# [9, 8, 9, 54, 3, 0, 8, 3, 5, 1]

# %%
l2 = l[::-1]
l2
# Out:
# [9, 8, 9, 54, 3, 0, 8, 3, 5, 1]

# %%
l
# Out:
# [1, 5, 3, 8, 0, 3, 54, 9, 8, 9]

# %%
l = [1,5,3,8,0,3,54,9,8,9]
l1 = l[int(len(l)/2)-1::-1]
l2 = l[int(len(l)/2):]
l1 + l2
# Out:
# [0, 8, 3, 5, 1, 3, 54, 9, 8, 9]

# %%
type(len(l))
# Out:
# int

# %%
l = [1,24,27,18,9,9,0,0,0,0]
l.reverse()
l
# Out:
# [0, 0, 0, 0, 9, 9, 18, 27, 24, 1]

# %%
l
# Out:
# [0, 0, 0, 0, 9, 9, 18, 27, 24, 1]

# %%
l.clear()
l
# Out:
# []

# %%
l = [1,5,3,8,0,3,54,9,8,9]
l.sort()
l
# Out:
# [0, 1, 3, 3, 5, 8, 8, 9, 9, 54]

# %%
l = [1,5,3,8,0,3,54,9,8,9]
l.sort(reverse = True)
l
# Out:
# [54, 9, 9, 8, 8, 5, 3, 3, 1, 0]

# %%
l = [1,5,3,8,0,3,54,9,8,9,11]
l1 = l[int(len(l)/2)-1::-1]
l2 = l[int(len(l)/2):]
l1 + l2
# Out:
# [0, 8, 3, 5, 1, 3, 54, 9, 8, 9, 11]

# %%
m = [1,2,3,4,5,6,7,8,9,0]
m[5:]
